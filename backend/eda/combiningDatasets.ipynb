# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
from wordcloud import WordCloud
from matplotlib.colors import ListedColormap

# %%
cols= ['dataset','text', 'logical_fallacies', 'source']
df = pd.DataFrame(columns= cols)

# %%
df_1 = pd.read_csv('../data/cleaned/1_logicClimate.csv')
df_2 = pd.read_csv('../data/cleaned/2_Huggingface_dataset.csv', index_col=0)
df_3 = pd.read_csv('../data/cleaned/3_CoCoLoFa_merged.csv')
df_4 = pd.read_csv('../data/cleaned/4_falcon_df_multilabel_annotations.csv')
df_5_1 = pd.read_csv('../data/cleaned/5_climate.csv')
df_5_2 = pd.read_csv('../data/cleaned/5_covid.csv')
df_6 = pd.read_csv('../data/cleaned/6_MAFALDA.csv')
df_8 = pd.read_csv('../data/cleaned/8_argotario.csv')
df_9 = pd.read_csv('../data/cleaned/9_Goffredo_used_in_MAFALDA_cleaned.csv')

# %% [markdown]
# ### 1

# %%
df_1['dataset']=1
df_1 = df_1.rename(columns={ 'original_url': 'source', 'source_article': 'text'})
df_1 = df_1.loc[:,cols ]
df_1 = df_1[df_1['logical_fallacies']!='fallacy of logic']
df_1.head()
# Out:
#    dataset                                               text
# 0        1  In June last year , a severe heatwave claimed ...  \
# 1        1  Diminishing sea ice is causing major walrus he...
# 2        1  A landmark report from the United Nations ’ sc...
# 3        1  The report “ is quite a shock , and quite conc...
# 4        1  The World Coal Association disputed the conclu...
#
#         logical_fallacies                                             source
# 0             intentional  https://www.theguardian.com/environment/2016/a...
# 1             intentional  https://www.theguardian.com/environment/2016/a...
# 2  fallacy of credibility  https://www.nytimes.com/2018/10/07/climate/ipc...
# 3  fallacy of credibility  https://www.nytimes.com/2018/10/07/climate/ipc...
# 4           false dilemma  https://www.nytimes.com/2018/10/07/climate/ipc...

# %% [markdown]
# ### 2

# %%
df_2['dataset']=2
df_2 = df_2.rename(columns={ 'statement': 'text', 'label': 'logical_fallacies'})
df_2 = df_2.loc[:,['dataset', 'text', 'logical_fallacies']]
df_2 = df_2[df_2['logical_fallacies']!='fallacy of logic']
df_2.head()
# Out:
#    dataset                                               text
# 0        2  The book is popular because it's good, and it'...  \
# 1        2  This policy is effective because it's popular,...
# 2        2  I know that our TV advertisements are more eff...
# 3        2  President Trump , who in the past has called g...
# 4        2  A commercial shows a group of friends all hang...
#
#        logical_fallacies
# 0     circular reasoning
# 1     circular reasoning
# 2  faulty generalization
# 3            intentional
# 4             ad populum

# %% [markdown]
# ### 3

# %%
df_3 = df_3[['fallacy', 'comment']]
df_3 = df_3.rename(columns={'fallacy':'logical_fallacies', 'comment': 'text' })
df_3['dataset'] = 3
df_3 = df_3.loc[:,['dataset','text', 'logical_fallacies']]
df_3.head()
# Out:
#    dataset                                               text
# 0        3  Lack of transparency in government isn't unexp...  \
# 1        3  While the issues discussed here should be addr...
# 2        3  The excuse that Brazilian municipalities do no...
# 3        3  This is what's to be expected of developing an...
# 4        3  Sad to say, I have to agree with you. Rulers c...
#
#      logical_fallacies
# 0                 none
# 1  appeal to authority
# 2                 none
# 3                 none
# 4  appeal to tradition

# %% [markdown]
# ### 4

# %%
df_4 = df_4[['fallacy','main_tweet']]
df_4 = df_4.rename(columns={'fallacy':'logical_fallacies','main_tweet': 'text' })
df_4.head()
# Out:
#                    logical_fallacies
# 0              ['None of the above']  \
# 1              ['None of the above']
# 2              ['None of the above']
# 3  ['Loaded Language', 'Ad Hominem']
# 4              ['None of the above']
#
#                                                 text
# 0  [main_tweet] [user104337]: @user @user ... @us...
# 1  [main_tweet] [user79987]: @user @user ... @use...
# 2  [main_tweet] [user104337]: @user @user ... @us...
# 3  [main_tweet] [user79987]: @user @user ... @use...
# 4  [main_tweet] [user47446]: @user @user ... @use...

# %%
i = 0

df_splitted_fallacies = pd.DataFrame(columns=['logical_fallacies', 'text'])
rows_to_delete=[]

for i in range(len(df_4)):
    # print(i)
    current_fallacies = df_4.iloc[i, 0]
    # print('current_fallacies:', current_fallacies)
    current_fallacies = current_fallacies.replace("'", "").replace('[', '').replace(']','')
    splitted_fallacies = current_fallacies.split(sep=',')
    if len(splitted_fallacies)==1:
        df_4.iloc[i, 0] = current_fallacies
    if len(splitted_fallacies)>1:
        for index, f in enumerate(splitted_fallacies):
            new_row = {'logical_fallacies':f, 'text': df_4.iloc[i, 1]}
            df_splitted_fallacies = pd.concat([df_splitted_fallacies, pd.DataFrame([new_row])])
            rows_to_delete.append(i)

# %%
 #remove duplicates
rows_to_delete = list(set(rows_to_delete))

#drop rows with multilabels
df_4 = df_4.drop(axis=0, index=rows_to_delete)

# %%
# concate new rows to dataframe
df_4 = pd.concat([df_4, df_splitted_fallacies])
df_4.head()
# Out:
#    logical_fallacies                                               text
# 0  None of the above  [main_tweet] [user104337]: @user @user ... @us...
# 1  None of the above  [main_tweet] [user79987]: @user @user ... @use...
# 2  None of the above  [main_tweet] [user104337]: @user @user ... @us...
# 4  None of the above  [main_tweet] [user47446]: @user @user ... @use...
# 5    Loaded Language  [main_tweet] [user1779]: @user @user ... @user...

# %%
df_4['dataset']=4
df_4 = df_4.loc[:,['dataset', 'text', 'logical_fallacies']]

# %% [markdown]
# ### 5

# %%
df_5_1.head()
# Out:
#                                 fact_checked_segment
# 0  “climate economists see a positive externality...  \
# 1  The latest U.N. science compendium asserts tha...
# 2  “‘If we are right, our study challenges decade...
# 3  “a killer analysis conducted by Craig Idso of ...
# 4  “Next year or the year after that, I think it ...
#
#                              comment_by_fact-checker         article
# 0  This is cherry-picking at its worst. You can a...   article36.txt  \
# 1  The recent US National Climate Assessment1 fin...  article130.txt
# 2  It only potentially challenges ONE method used...             NaN
# 3  This publication is not peer-reviewed, cherry-...   article45.txt
# 4  I would also add that predictions of an ice-fr...   article33.txt
#
#   logical_fallacies
# 0    Cherry Picking
# 1    Cherry Picking
# 2    Cherry Picking
# 3    Cherry Picking
# 4    Cherry Picking

# %%
df_5_1 = df_5_1[['fact_checked_segment', 'logical_fallacies', 'article']]
df_5_1 = df_5_1.rename(columns={'fact_checked_segment': 'text', 'article': 'source'})
df_5_1['dataset'] = 5
df_5_1 = df_5_1.loc[:,['dataset', 'text', 'logical_fallacies', 'source']]
df_5_1.head()
# Out:
#    dataset                                               text
# 0        5  “climate economists see a positive externality...  \
# 1        5  The latest U.N. science compendium asserts tha...
# 2        5  “‘If we are right, our study challenges decade...
# 3        5  “a killer analysis conducted by Craig Idso of ...
# 4        5  “Next year or the year after that, I think it ...
#
#   logical_fallacies          source
# 0    Cherry Picking   article36.txt
# 1    Cherry Picking  article130.txt
# 2    Cherry Picking             NaN
# 3    Cherry Picking   article45.txt
# 4    Cherry Picking   article33.txt

# %%
df_5_2.head()

df_5_2 = df_5_2[['claim', 'logical_fallacies']]
df_5_2 = df_5_2.rename(columns={'claim': 'text' })
df_5_2['dataset'] = 5
df_5_2 = df_5_2.loc[:,['dataset', 'text', 'logical_fallacies']]
df_5_2.head()
# Out:
#    dataset                                               text
# 0        5  In November 2020, Ticketmaster announced that ...  \
# 1        5  Says that “the way to reach ‘herd immunity’ is...
# 2        5  The public won’t be able to claim compensation...
# 3        5  “vaccinated children appear to be significantl...
# 4        5  The WHO now says a child’s presence in school ...
#
#   logical_fallacies
# 0    Cherry Picking
# 1    Cherry Picking
# 2    Cherry Picking
# 3    Cherry Picking
# 4    Cherry Picking

# %% [markdown]
# ### 6

# %%
df_6.head()
df_6 = df_6.rename(columns={'text_only': 'text', 'labels_only': 'logical_fallacies'})
df_6['dataset'] = 6
df_6 = df_6.loc[:,['dataset', 'text', 'logical_fallacies']]
df_6.head()
# Out:
#    dataset                                               text
# 0        6  Reading everyone's comments has made me change...  \
# 1        6  Two of my best friends are really introverted,...
# 2        6  Someone once told me they have an"alt" cause t...
# 3        6  Joe Biden will lose to Trump if he is the nomi...
# 4        6  America is the best place to live, because it'...
#
#       logical_fallacies
# 0        slippery slope
# 1  hasty generalization
# 2         false analogy
# 3  guilt by association
# 4    circular reasoning

# %% [markdown]
# ### 8

# %%
pd.set_option('display.max_colwidth', None)
df_8.tail(10)
# Out:
#       logical_fallacies
# 1334         No Fallacy  \
# 1335         Ad Hominem
# 1336         No Fallacy
# 1337         No Fallacy
# 1338         No Fallacy
# 1339  Appeal to Emotion
# 1340         No Fallacy
# 1341         No Fallacy
# 1342         No Fallacy
# 1343         No Fallacy
#
#                                                                                                                                                                                                                                 claim
# 1334                                                                                                                                                  Nowadays, nuclear power is the most effective and safest energy source we have.
# 1335                                                                                                                                                         What kind of dumb question is that? Stupid answers get stupid responses.
# 1336        Accepting immigrants in Europe must be taken seriously and deserves coordination and investments, as we cannot directly influence the sources of immigration - ending the war in Libya or changing the regime in Eritrea.
# 1337                                                                                                  So far there is a limit of 0.5 per-mille. With this amount of alcohol you are able to drive safely. Therefore the answer is no.
# 1338                                                                                                                                                                           Animal testing for medical purposes should be allowed.
# 1339  Sure, let's make America great again! Go ask ordinary people in Afghanistan. Go check with bombed out schools in Iraq after "freeing" the country. Talk to refugees who had to leave their homes. Maybe you'll figure out then.
# 1340                        No. Greece is one of the countries, that, in its history, has contributed to an european union the most. Throwing this country out of it, would therefore destroy confidence in this community, the most.
# 1341                                                                                    Interestingly the boys I know from single sex schools seem more against it than the girls and they do feel they were socially hampered a bit.
# 1342                                                                                                                                                                          It has, earlier the people talked more with each other.
# 1343                                                                                                                                                                                                               It's a time killer

# %%
df_8.head()
df_8 = df_8.dropna()
df_8 = df_8.rename(columns={'claim': 'text' })
df_8['dataset'] = 8
df_8 = df_8.loc[:,['dataset', 'text', 'logical_fallacies']]
df_8.head()
# Out:
#    dataset
# 0        8  \
# 1        8
# 2        8
# 3        8
# 4        8
#
#                                                                                                                                                 text
# 0                                     No, imagine you were a teacher and everybody would just concentrate on their smartphones? How would that feel?  \
# 1                                                                                           The moon is so far away, we should focus on our society.
# 2                                                     The green party in Germany has the opinion, that nuclear reactors are bad for us. It is not ok
# 3  No, not at all. Nowadays kids spend all time playing around with tablets and smartphones, which is kinda detrimental to their proper development.
# 4                                                                         Yes,  whoever drinks and drives has a bad reaction time. People might die.
#
#       logical_fallacies
# 0     Appeal to Emotion
# 1           Red Herring
# 2  Irrelevant Authority
# 3           Red Herring
# 4            No Fallacy

# %% [markdown]
# ### 9

# %%
df_9 = df_9[['text', 'fallacy']]
df_9 = df_9.rename(columns={'fallacy': 'logical_fallacies' })
df_9['dataset'] = 9
df_9 = df_9.loc[:,['dataset', 'text', 'logical_fallacies']]
df_9.head()
# Out:
#    dataset
# 0        9  \
# 1        9
# 2        9
# 3        9
# 4        9
#
#                                                                                               text
# 0  And I think you get a certain arrogance, bureaucratic arrogance, if people stay there too long.  \
# 1                                               Bill Clinton simply has trouble telling the truth?
# 2                                             he has a long record of engaging in racist behavior.
# 3                                                                    she's got no business ability
# 4                                                                            she doesn't have that
#
#   logical_fallacies
# 0        Ad Hominem
# 1        Ad Hominem
# 2        Ad Hominem
# 3        Ad Hominem
# 4        Ad Hominem

# %% [markdown]
# ### lower case, underscore

# %%
def adjust(data):
    data['logical_fallacies']=data['logical_fallacies'].map(lambda x: x.lower().replace(' ', '_'))
    return data

df_1 = adjust(df_1)
df_2 = adjust(df_2)
df_3 = adjust(df_3)
df_4 = adjust(df_4)
df_5_1 = adjust(df_5_1)
df_5_2= adjust(df_5_2)
df_6 = adjust(df_6)
df_8 = adjust(df_8)
df_9 = adjust(df_9)

# %%
# dfList = [df_1, df_2, df_3, df_4 ,df_5_1, df_5_2, df_8, df_9]
# for d in dfList:
#     print (d.columns)

# %% [markdown]
# ### concat

# %%
df = pd.concat([df_1, df_2, df_3, df_4, df_5_1, df_5_2, df_6, df_8, df_9])
df = df.reset_index(drop=True)
df
# Out:
#        dataset
# 0            1  \
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 20161        9
# 20162        9
# 20163        9
# 20164        9
# 20165        9
#
#                                                                                                                                                                                                                                                                                                                                                         text
# 0                                            In June last year , a severe heatwave claimed over 1,000 lives in Karachi , Pakistan . Severe drought caused food shortages for millions of people in Ethiopia , with a lack of rainfall resulting in “ intense and widespread ” forest fires in Indonesia that belched out a vast quantity of greenhouse gas .  \
# 1      Diminishing sea ice is causing major walrus herds to haul themselves out on to land . Arctic marine species , such as snailfish and polar cod , are being pushed out of the region by species coming from further south , attracted to the warming waters . A huge algal bloom off the west coast of North America harmed marine life and fisheries .
# 2                       A landmark report from the United Nations ’ scientific panel on climate change paints a far more dire picture of the immediate consequences of climate change than previously thought and says that avoiding the damage requires transforming the world economy at a speed and scale that has “ no documented historic precedent . ”
# 3                                                                                                                  The report “ is quite a shock , and quite concerning , ” said Bill Hare , an author of previous I.P.C.C . reports and a physicist with Climate Analytics , a nonprofit organization . “ We were not aware of this just a few years ago. ”
# 4                                                                                                                                                                                                                                             The World Coal Association disputed the conclusion that stopping global warming calls for an end of coal use .
# ...                                                                                                                                                                                                                                                                                                                                                      ...
# 20161                                                                                                                                                                                                                                                                                                                         separation of church and state
# 20162                                                                                                                                                                                                                                                                                                                         Our character is on the ballot
# 20163                                                                                                                                                                                                                                                                                                                                       Show up and vote
# 20164                                                                                                                                                                                                                                                                                                          I don't believe that Hillary has the stamina.
# 20165                                                                                                                                                                                                                                                                                                                  But Hillary Clinton wanted the wall .
#
#             logical_fallacies
# 0                 intentional  \
# 1                 intentional
# 2      fallacy_of_credibility
# 3      fallacy_of_credibility
# 4               false_dilemma
# ...                       ...
# 20161                 slogans
# 20162                 slogans
# 20163                 slogans
# 20164              ad_hominem
# 20165              ad_hominem
#
#                                                                                                                    source
# 0      https://www.theguardian.com/environment/2016/aug/02/environment-climate-change-records-broken-international-report
# 1      https://www.theguardian.com/environment/2016/aug/02/environment-climate-change-records-broken-international-report
# 2                                                https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html
# 3                                                https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html
# 4                                                https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html
# ...                                                                                                                   ...
# 20161                                                                                                                 NaN
# 20162                                                                                                                 NaN
# 20163                                                                                                                 NaN
# 20164                                                                                                                 NaN
# 20165                                                                                                                 NaN
#
# [20166 rows x 4 columns]

# %%
df = df[df['logical_fallacies']!='to_clean']

# %%
df = df[df['logical_fallacies']!='intentional']

# %%
fall_list = df['logical_fallacies'].unique().tolist()
fall_list.sort()
fall_list
# Out:
# ['_ad_hominem',
#  '_appeal_to_fear',
#  '_appeal_to_ridicule',
#  '_false_dilemma',
#  '_hasty_generalization',
#  'ad_hominem',
#  'ad_populum',
#  'appeal_to_(false)_authority',
#  'appeal_to_anger',
#  'appeal_to_authority',
#  'appeal_to_emotion',
#  'appeal_to_fear',
#  'appeal_to_majority',
#  'appeal_to_nature',
#  'appeal_to_pity',
#  'appeal_to_positive_emotion',
#  'appeal_to_ridicule',
#  'appeal_to_tradition',
#  'appeal_to_worse_problems',
#  'causal_oversimplification',
#  'cherry_picking',
#  'circular_reasoning',
#  'equivocation',
#  'evading_the_burden_of_proof',
#  'fallacy_of_credibility',
#  'fallacy_of_division',
#  'fallacy_of_extension',
#  'fallacy_of_relevance',
#  'false_analogy',
#  'false_authority',
#  'false_causality',
#  'false_cause',
#  'false_dilemma',
#  'faulty_generalization',
#  'guilt_by_association',
#  'hasty_generalization',
#  'irrelevant_authority',
#  'loaded_language',
#  'no_fallacy',
#  'none',
#  'none_of_the_above',
#  'post_hoc',
#  'red_herring',
#  'slippery_slope',
#  'slogans',
#  'straw_man',
#  'strawman',
#  'tu_quoque',
#  'vagueness']

# %%
labels ={
    'none_of_the_above': 'none',
    '_ad_hominem': 'ad_hominem',
    '_hasty_generalization':'hasty_generalization',
    '_appeal_to_ridicule': 'appeal_to_ridicule',
    '_false_dilemma': 'false_dilemma',
    '_appeal_to_fear':'appeal_to_fear',
    'no_fallacy': 'none',
    'straw_man': 'strawman',
    'appeal_to_fear': 'appeal_to_emotion',
    'appeal_to_anger': 'appeal_to_emotion',
    'appeal_to_pity': 'appeal_to_emotion',
    'appeal_to_positive_emotion': 'appeal_to_emotion',
    'appeal_to_(false)_authority' : 'appeal_to_authority',
    'false_authority': 'appeal_to_authority',
    'hasty_generalization': 'faulty_generalization'
}

df= df.replace(labels)

# %%
sns.countplot(data = df, y ='logical_fallacies')
plt.show()

# %%
df.groupby('logical_fallacies')['logical_fallacies'].value_counts().sort_values(ascending=False)
# Out:
# logical_fallacies
# none                           5482
# appeal_to_emotion              1878
# faulty_generalization          1538
# ad_hominem                     1244
# false_dilemma                  1043
# appeal_to_authority             744
# slippery_slope                  638
# appeal_to_nature                544
# false_causality                 543
# appeal_to_worse_problems        535
# appeal_to_tradition             518
# fallacy_of_relevance            499
# appeal_to_majority              492
# ad_populum                      492
# loaded_language                 457
# fallacy_of_credibility          397
# fallacy_of_extension            382
# red_herring                     271
# circular_reasoning              264
# appeal_to_ridicule              250
# equivocation                    224
# irrelevant_authority            157
# false_cause                     129
# cherry_picking                  118
# vagueness                        81
# evading_the_burden_of_proof      62
# slogans                          52
# strawman                         44
# hasty_generalization             41
# false_analogy                    41
# appeal_to_fear                   30
# post_hoc                         27
# causal_oversimplification        13
# tu_quoque                         3
# fallacy_of_division               2
# guilt_by_association              2
# Name: count, dtype: int64

# %% [markdown]
# ## Drop missing values

# %%
df = df.dropna(subset=['text'])

# %% [markdown]
# ## Clean text

# %%
df.head()
# Out:
#    dataset
# 2        1  \
# 3        1
# 4        1
# 5        1
# 6        1
#
#                                                                                                                                                                                                                                                                                                                                    text
# 2  A landmark report from the United Nations ’ scientific panel on climate change paints a far more dire picture of the immediate consequences of climate change than previously thought and says that avoiding the damage requires transforming the world economy at a speed and scale that has “ no documented historic precedent . ”  \
# 3                                                                                             The report “ is quite a shock , and quite concerning , ” said Bill Hare , an author of previous I.P.C.C . reports and a physicist with Climate Analytics , a nonprofit organization . “ We were not aware of this just a few years ago. ”
# 4                                                                                                                                                                                                                        The World Coal Association disputed the conclusion that stopping global warming calls for an end of coal use .
# 5                                                                                                          In a statement , Katie Warrick , its interim chief executive , noted that forecasts from the International Energy Agency , a global analysis organization , “ continue to see a role for coal for the foreseeable future . ”
# 6                                                                                                                                                                      Refusing to approve the document would place the United States at odds with many nations and show it rejecting established academic science on the world stage .
#
#         logical_fallacies
# 2  fallacy_of_credibility  \
# 3  fallacy_of_credibility
# 4           false_dilemma
# 5  fallacy_of_credibility
# 6       appeal_to_emotion
#
#                                                                      source
# 2  https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html
# 3  https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html
# 4  https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html
# 5  https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html
# 6  https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html

# %%
df.sort_values(by='text')
# Out:
#        dataset
# 2674         2  \
# 2209         2
# 16882        5
# 4520         2
# 3763         2
# ...        ...
# 16213        5
# 16146        5
# 16741        5
# 16653        5
# 956          1
#
#                                                                                                                                                                                                                                                                                                                                            text
# 2674                                                                                                       \nThe presence of police at protests cause an escalation of violence. It was the case that at the protest last night attended by uniformed police, there was an escalation of violence. Therefore, police should not be at protests.  \
# 2209                                                                                                             Homosexuality is / ought to be morally wrong (moral property) because it is not normal (natural property).\nor\nHomosexuality is not normal (natural property); therefore, it is / ought to be morally wrong (moral property).
# 16882                                                                                                                                                                                                                                                                                                    COVID-19 vaccines caused miscarriages
# 4520                                                                                                                                                                                                                                                                                      Circular definition: a definition that is circular.\n
# 3763    Doug is convinced he has lucky underwear. One time when he forgot to put on his lucky underwear, he got a parking ticket. Doug concludes that because he forgot to wear his lucky underwear, he got the ticket. Doug doesn't wash his lucky underwear often. This part isn't relevant to the example, but it is disturbing nonetheless.
# ...                                                                                                                                                                                                                                                                                                                                         ...
# 16213                                                                                                                                          ” ‘You’ve only got to look at Singapore. It’s two-and-a-half times higher than the worst-case scenario for climate change, and it’s one of the most desirable cities in the world to live in.’ ”
# 16146                                                                                                                                          ” ‘You’ve only got to look at Singapore. It’s two-and-a-half times higher than the worst-case scenario for climate change, and it’s one of the most desirable cities in the world to live in.’ ”
# 16741                                                                                                                                                                                                                 ” ‘and it’s only got to take one sizable volcano to erupt and all the models, everything else, is right off the board’ ”
# 16653                                                                                                                                                                                                                 ” ‘and it’s only got to take one sizable volcano to erupt and all the models, everything else, is right off the board’ ”
# 956                                                                                                                                                                                • Empirical evidence directly contradicts claims that increased carbon dioxide has reduced human wellbeing . In fact , human wellbeing has never been higher
#
#             logical_fallacies
# 2674          false_causality  \
# 2209   fallacy_of_credibility
# 16882                post_hoc
# 4520       circular_reasoning
# 3763          false_causality
# ...                       ...
# 16213           false_analogy
# 16146          cherry_picking
# 16741                    none
# 16653             red_herring
# 956           false_causality
#
#                                                                                                source
# 2674                                                                                              NaN
# 2209                                                                                              NaN
# 16882                                                                                             NaN
# 4520                                                                                              NaN
# 3763                                                                                              NaN
# ...                                                                                               ...
# 16213                                                                                             NaN
# 16146                                                                                             NaN
# 16741                                                                                             NaN
# 16653                                                                                             NaN
# 956    https://www.breitbart.com/europe/2021/02/07/delingpole-study-disputes-earth-climate-emergency/
#
# [19202 rows x 4 columns]

# %%
import re
#https://docs.python.org/3/library/re.html

#administration \' s
# \n

def clean_text(text):
    # Remove POST
    #text = re.sub(r'^.*?POST:', '', text, flags=re.DOTALL)
    # Remove any remaining "POST:" occurrences
    #text = re.sub(r'POST:', '', text)
    # Remove '\r\n' and extra whitespace
    #text = re.sub(r'\r\n', ' ', text)
    # Remove '\n'
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\r', '', text)
    # Remove " in beginning of text
    text = re.sub(r'^"', '', text)
    # Remove " at end of text
    text = re.sub(r'"$', '', text)
     # Remove ' in beginning of text
    text = re.sub(r"^'", '', text)
    # Remove ' at end of text
    text = re.sub(r"'$", '', text)
    # Remove (number or text) at beginning of text
    text = re.sub(r"^\([^)]*\)", '', text)
    # Remove \x80\x9d
    text = re.sub(r'\x80\x9d', '', text)
     # Remove : in beginning of text
    text = re.sub(r"^:", '', text)
    # Remove · in beginning of text
    text = re.sub(r"^•", '', text)
    # Remove ” in beginning of text
    text = re.sub(r"^”", '', text)
    # Remove @user
    text = re.sub(r'@user', '', text)
    # Remove [main_tweet], [user104337]
    text = re.sub(r"\[main_tweet\]", '', text)
    text = re.sub(r"\[user\d+\]", '', text)
     # Remove punctuation
    text = re.sub(r'\W', ' ', text)
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    return text.strip()

df['text'] = df['text'].apply(clean_text)

# %%
df.loc[1641, "text"]
# Out:
# 'rather than on his arguments or opinions'

# %%
txt = "hallo \r chocolatecake"

#Check if the string starts with 'hello':
#x = re.sub(r"\[user\d+\]", '', txt)
x = re.sub(r'\r', '', txt)
# x = re.sub(r"^\[[^)]*\]", '', txt)
print(x)
# Out:
# hallo  chocolatecake

# %% [markdown]
# ## Duplicates

# %%
df.head()
# Out:
#    dataset
# 2        1  \
# 3        1
# 4        1
# 5        1
# 6        1
#
#                                                                                                                                                                                                                                                                                                                            text
# 2  A landmark report from the United Nations scientific panel on climate change paints a far more dire picture of the immediate consequences of climate change than previously thought and says that avoiding the damage requires transforming the world economy at a speed and scale that has no documented historic precedent  \
# 3                                                                                                          The report is quite a shock and quite concerning said Bill Hare an author of previous I P C C reports and a physicist with Climate Analytics a nonprofit organization We were not aware of this just a few years ago
# 4                                                                                                                                                                                                                  The World Coal Association disputed the conclusion that stopping global warming calls for an end of coal use
# 5                                                                                                                  In a statement Katie Warrick its interim chief executive noted that forecasts from the International Energy Agency a global analysis organization continue to see a role for coal for the foreseeable future
# 6                                                                                                                                                                Refusing to approve the document would place the United States at odds with many nations and show it rejecting established academic science on the world stage
#
#         logical_fallacies
# 2  fallacy_of_credibility  \
# 3  fallacy_of_credibility
# 4           false_dilemma
# 5  fallacy_of_credibility
# 6       appeal_to_emotion
#
#                                                                      source
# 2  https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html
# 3  https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html
# 4  https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html
# 5  https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html
# 6  https://www.nytimes.com/2018/10/07/climate/ipcc-climate-report-2040.html

# %%
df_duplicated = df[df.duplicated(["text", "logical_fallacies"], keep=False)==True]
df_duplicated = df_duplicated.sort_values(by='text')
df_duplicated.head(20)
# Out:
#       dataset
# 2715        2  \
# 37          1
# 1252        1
# 2886        2
# 5438        2
# 1253        1
# 3346        2
# 427         1
# 422         1
# 4466        2
# 190         1
# 1328        2
# 3927        2
# 5193        2
# 1133        1
# 1136        1
# 29          1
# 2226        2
# 3420        2
# 816         1
#
#                                                                                                                                                                                                                                                               text
# 2715                                                                                                                                                           18 years after 1998 global warming still has not created the runaway warming we were told to expect  \
# 37                                                                                                                                                             18 years after 1998 global warming still has not created the runaway warming we were told to expect
# 1252                                                                                                                              2 CO2 is a greenhouse gas without which life on earth is not possible but adding it to theatmosphere should lead to some warming
# 2886                                                                                                                              2 CO2 is a greenhouse gas without which life on earth is not possible but adding it to theatmosphere should lead to some warming
# 5438     4 Over this period the past two centuries the global mean temperature has increasedslightly and erratically by about 1 8 degrees Fahrenheit or one degree Celsius but only sincethe 1960 s have man s greenhouse emissions been sufficient to play a role
# 1253     4 Over this period the past two centuries the global mean temperature has increasedslightly and erratically by about 1 8 degrees Fahrenheit or one degree Celsius but only sincethe 1960 s have man s greenhouse emissions been sufficient to play a role
# 3346                                                                                                                                 A Republican congressman from Colorado Ken Buck recently called one military proposal part of a radical climate change agenda
# 427                                                                                                                                  A Republican congressman from Colorado Ken Buck recently called one military proposal part of a radical climate change agenda
# 422                                                                                                                                  A Republican congressman from Colorado Ken Buck recently called one military proposal part of a radical climate change agenda
# 4466                                                                                                                                 A Republican congressman from Colorado Ken Buck recently called one military proposal part of a radical climate change agenda
# 190                                                                                                             A comprehensive list would run to hundreds if not thousands of elements none of which scientists would claim to understand with absolute precision
# 1328                                                                                                            A comprehensive list would run to hundreds if not thousands of elements none of which scientists would claim to understand with absolute precision
# 3927                                                                                                            A defiant generalist in an era of increasingly specialised study and a mischievous provocateur Lovelock is regarded by many as a scientific genius
# 5193                                                                                                            A defiant generalist in an era of increasingly specialised study and a mischievous provocateur Lovelock is regarded by many as a scientific genius
# 1133                                                                                                            A defiant generalist in an era of increasingly specialised study and a mischievous provocateur Lovelock is regarded by many as a scientific genius
# 1136                                                                                                            A defiant generalist in an era of increasingly specialised study and a mischievous provocateur Lovelock is regarded by many as a scientific genius
# 29    A domino like cascade of melting ice warming seas shifting currents and dying forests could tilt the Earth into a hothouse state beyond which human efforts to reduce emissions will be increasingly futile a group of leading climate scientists has warned
# 2226  A domino like cascade of melting ice warming seas shifting currents and dying forests could tilt the Earth into a hothouse state beyond which human efforts to reduce emissions will be increasingly futile a group of leading climate scientists has warned
# 3420                                                                                                                                                                         A global network of 500 scientists and professionals has prepared this urgent message
# 816                                                                                                                                                                          A global network of 500 scientists and professionals has prepared this urgent message
#
#            logical_fallacies
# 2715              ad_populum  \
# 37                ad_populum
# 1252    fallacy_of_relevance
# 2886    fallacy_of_relevance
# 5438  fallacy_of_credibility
# 1253  fallacy_of_credibility
# 3346              ad_hominem
# 427   fallacy_of_credibility
# 422               ad_hominem
# 4466  fallacy_of_credibility
# 190               ad_populum
# 1328              ad_populum
# 3927  fallacy_of_credibility
# 5193              ad_populum
# 1133  fallacy_of_credibility
# 1136              ad_populum
# 29     faulty_generalization
# 2226   faulty_generalization
# 3420              ad_populum
# 816   fallacy_of_credibility
#
#                                                                                                                                                                 source
# 2715                                                                                                                                                               NaN
# 37                                              https://www.forbes.com/sites/jamestaylor/2016/01/14/2015-was-not-even-close-to-hottest-year-on-record/?sh=7170b4ef5539
# 1252                                                                                                                https://www.facebook.com/watch/?v=3169298993112935
# 2886                                                                                                                                                               NaN
# 5438                                                                                                                                                               NaN
# 1253                                                                                                                https://www.facebook.com/watch/?v=3169298993112935
# 3346                                                                                                                                                               NaN
# 427                                                       https://www.nytimes.com/2016/09/04/science/flooding-of-coast-caused-by-global-warming-has-already-begun.html
# 422                                                       https://www.nytimes.com/2016/09/04/science/flooding-of-coast-caused-by-global-warming-has-already-begun.html
# 4466                                                                                                                                                               NaN
# 190   https://www.bostonglobe.com/opinion/columns/2017/03/14/why-are-climate-change-models-flawed-because-climate-science-incomplete/hekwjPBTScRpFyXaXnrWhI/story.html
# 1328                                                                                                                                                               NaN
# 3927                                                                                                                                                               NaN
# 5193                                                                                                                                                               NaN
# 1133                                        https://www.theguardian.com/environment/2016/sep/30/james-lovelock-interview-by-end-of-century-robots-will-have-taken-over
# 1136                                        https://www.theguardian.com/environment/2016/sep/30/james-lovelock-interview-by-end-of-century-robots-will-have-taken-over
# 29                                          https://www.theguardian.com/environment/2018/aug/06/domino-effect-of-climate-events-could-push-earth-into-a-hothouse-state
# 2226                                                                                                                                                               NaN
# 3420                                                                                                                                                               NaN
# 816                                                                                            https://clintel.nl/wp-content/uploads/2019/09/ED-brochureversieNWA4.pdf

# %%
df = df.drop_duplicates(subset=['text', 'logical_fallacies'], keep='first')

# %%
df.duplicated(['text']).sum()
# Out:
# 638

# %%
df.duplicated(['text', 'logical_fallacies']).sum()
# Out:
# 0

# %%
df['dataset'].value_counts().sort_index()
# Out:
# dataset
# 1     867
# 2    3174
# 3    6905
# 4    3261
# 5     784
# 6     169
# 8    1328
# 9    1598
# Name: count, dtype: int64

# %% [markdown]
# ## Select fallacies

# %%
df.groupby('logical_fallacies')['logical_fallacies'].value_counts().sort_values(ascending=False)
# Out:
# logical_fallacies
# none                           5436
# appeal_to_emotion              1681
# faulty_generalization          1384
# ad_hominem                     1116
# false_dilemma                   981
# appeal_to_authority             734
# slippery_slope                  632
# appeal_to_nature                544
# appeal_to_worse_problems        534
# appeal_to_tradition             518
# appeal_to_majority              492
# false_causality                 456
# loaded_language                 454
# ad_populum                      421
# fallacy_of_relevance            393
# fallacy_of_extension            307
# fallacy_of_credibility          273
# red_herring                     268
# appeal_to_ridicule              250
# circular_reasoning              248
# equivocation                    197
# irrelevant_authority            157
# false_cause                     115
# cherry_picking                  110
# vagueness                        77
# evading_the_burden_of_proof      57
# slogans                          50
# strawman                         44
# hasty_generalization             41
# false_analogy                    39
# appeal_to_fear                   30
# post_hoc                         27
# causal_oversimplification        13
# tu_quoque                         3
# fallacy_of_division               2
# guilt_by_association              2
# Name: count, dtype: int64

# %%
# show the quantity of all the fallacies combined againes the "none"
df["fallacy_grouped"] = df["logical_fallacies"].apply(lambda x: "Fallacy-Free" if x == "none" else "Fallacy")

# Count values
counts = df["fallacy_grouped"].value_counts()

# Barplot
plt.style.use('stylesheet.mplstyle')
sns.barplot(x=counts.index, y=counts.values)
plt.title("Fallacy vs None")
plt.xlabel(" ")
plt.ylabel("Frequency")
plt.show()

# %%
# Create pie chart using stylesheet
# plt.style.use('stylesheet.mplstyle')
fig, ax = plt.subplots()
labels = ["Fallacy", "Fallacy-Free"]

# Get value counts in sorted order (alphabetically: 'fallacy', 'none')
counts = df["fallacy_grouped"].value_counts().sort_index()

# Create pie chart
ax.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title(" ")
plt.show()

# %%
# 1. Filter out 'none' values
filtered_fallacies = df[df["logical_fallacies"] != "none"]

# 2. Count frequency of each unique fallacy
fallacy_freq = filtered_fallacies["logical_fallacies"].value_counts().to_dict()

# 3. Set up styling
colormap = ['#FD6237', '#B4D68F', '#BEB5E8', '#F4B317']
background = '#F7ECDB'

# 4. Create word cloud using frequencies
wordcloud = WordCloud(
    background_color=background,
    colormap=ListedColormap(colormap),
    width=800,
    height=400
).generate_from_frequencies(fallacy_freq)

# 5. Display
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title(" ")
plt.show()

# %%
most_freq_fallacies = df.groupby('logical_fallacies')['logical_fallacies'].value_counts().sort_values(ascending=False).index[:7]
most_freq_fallacies # include 'slippery_slope'
# Out:
# Index(['none', 'appeal_to_emotion', 'faulty_generalization', 'ad_hominem',
#        'false_dilemma', 'appeal_to_authority', 'slippery_slope'],
#       dtype='object', name='logical_fallacies')

# %% [markdown]
# ## Save dataset

# %%
df = df[df['logical_fallacies'].isin(most_freq_fallacies)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11964 entries, 4 to 20165
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dataset            11964 non-null  int64
#  1   text               11964 non-null  object
#  2   logical_fallacies  11964 non-null  object
#  3   source             531 non-null    object
#  4   fallacy_grouped    11964 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 560.8+ KB

# %%
df['logical_fallacies'].value_counts()
# Out:
# logical_fallacies
# none                     5436
# appeal_to_emotion        1681
# faulty_generalization    1384
# ad_hominem               1116
# false_dilemma             981
# appeal_to_authority       734
# slippery_slope            632
# Name: count, dtype: int64

# %% [markdown]
# ## Fine-Cleaning Dataset

# %%
df_clean2 = df.copy()

# %%
df_clean2["logical_fallacies"].value_counts()
# Out:
# logical_fallacies
# none                     5436
# appeal_to_emotion        1681
# faulty_generalization    1384
# ad_hominem               1116
# false_dilemma             981
# appeal_to_authority       734
# slippery_slope            632
# Name: count, dtype: int64

# %%
# Remove the following words and clean extra spaces
words_to_remove = ['uspoli', 'cdnpoli', 'pnpcbc', 'UKpolitics', 'auspol', 'polcan', 'eupol', 'nzpol', 'ctvpp']
pattern = r'\b(' + '|'.join(map(re.escape, words_to_remove)) + r')\b'

df_clean2["text"] = df_clean2["text"].str.replace(pattern, '', regex=True).str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
# Look at one word texts and drop rows that do not make sense, e.g., testtesttesttest or are redundant
df_clean2 = df_clean2.drop(index=17908) #tessttetttetete	
df_clean2 = df_clean2.drop(index=18030) # tesforArgumentforAr
df_clean2 = df_clean2.drop(index=17573) # duplicate: yes
df_clean2 = df_clean2.drop(index=18337) # duplicate: no

# %%
pd.set_option("display.max_rows", None)
df_filtered = df_clean2[df_clean2['text'].str.split().str.len() == 1]

# %% [markdown]
# ### Remove duplicated text

# %%
# Look at duplicate text
df_duplicated_text = df_clean2[df_clean2.duplicated(["text"], keep=False)==True]
df_duplicated_text.shape
# Out:
# (220, 5)

# %%
# Drop duplicates
df_clean2 = df_clean2.drop_duplicates(subset=['text'], keep=False)
df_clean2.shape
# Out:
# (11740, 5)

# %% [markdown]
# ### Save dataframe without duplicates

# %%
df_clean2.to_csv("../data/data.csv", index=False)
